# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout, Input

# %%
data= pd.read_csv(r"C:\Users\hsynt\Downloads\Selcuk Abi\Selcuk Abi\VeriSeti2.csv")

# %%
# Özellik ve Hedef Ayrımı
X = data.drop(columns=['Target_10', 'adjclose'])
y = data['Target_10']

# Zaman Serisi Formatına Getirme
def create_sequences(data, target, seq_length):
    sequences, targets = [], []
    for i in range(len(data) - seq_length):
        sequences.append(data[i:i + seq_length])
        targets.append(target[i + seq_length])
    return np.array(sequences), np.array(targets)

SEQ_LENGTH = 10
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_seq, y_seq = create_sequences(X_scaled, y.values, SEQ_LENGTH)

# Eğitim ve test kümelerinin oluşturulması
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42, stratify=y_seq)

# PCA ve LDA Veri Hazırlığı
X_flat = X_seq.reshape(X_seq.shape[0], -1)  # Düzleştirilmiş veri

pca = PCA(n_components=10)
X_train_pca = pca.fit_transform(X_train.reshape(X_train.shape[0], -1))
X_test_pca = pca.transform(X_test.reshape(X_test.shape[0], -1))

lda = LDA(n_components=1)
X_train_lda = lda.fit_transform(X_train.reshape(X_train.shape[0], -1), y_train)
X_test_lda = lda.transform(X_test.reshape(X_test.shape[0], -1))

# GRU Modeli Tanımlama
def build_gru_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        GRU(64, activation='relu', return_sequences=False),
        Dropout(0.2),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Performans Hesaplama
results = []
threshold = 60  # Underfitting için eşik

for reduction, X_tr, X_te, y_tr, y_te in zip(
    ['No PCA/LDA', 'PCA', 'LDA'],
    [X_train, X_train_pca, X_train_lda],
    [X_test, X_test_pca, X_test_lda],
    [y_train, y_train, y_train],
    [y_test, y_test, y_test]
):
    if reduction == 'No PCA/LDA':
        X_tr = X_tr.reshape(X_tr.shape[0], X_tr.shape[1], X_tr.shape[2])  # 3D giriş
        X_te = X_te.reshape(X_te.shape[0], X_te.shape[1], X_te.shape[2])
    else:
        # PCA ve LDA için uygun giriş formatı
        X_tr = np.tile(X_tr, (1, SEQ_LENGTH)).reshape(X_tr.shape[0], SEQ_LENGTH, -1)
        X_te = np.tile(X_te, (1, SEQ_LENGTH)).reshape(X_te.shape[0], SEQ_LENGTH, -1)

    gru_model = build_gru_model(X_tr.shape[1:])
    history = gru_model.fit(X_tr, y_tr, epochs=10, batch_size=32, verbose=1, validation_data=(X_te, y_te))

    # Eğitim ve Test Kayıpları
    train_acc = history.history['accuracy'][-1] * 100
    test_acc = history.history['val_accuracy'][-1] * 100
    train_loss = history.history['loss'][-1]
    test_loss = history.history['val_loss'][-1]

    # Aşırı ve Yetersiz Öğrenme Kontrolü
    overfit = train_acc - test_acc > 5  # %5'ten fazla fark varsa aşırı öğrenme
    underfit = train_acc < threshold and test_acc < threshold

    results.append({
        'Reduction': reduction,
        'Model': 'GRU',
        'Train Accuracy (%)': train_acc,
        'Test Accuracy (%)': test_acc,
        'Train Loss': train_loss,
        'Test Loss': test_loss,
        'Overfitting': overfit,
        'Underfitting': underfit
    })

# Performans Sonuçlarını Görselleştirme
results_df = pd.DataFrame(results)

# Performans Sonuçları Tablosu
print("Performans Sonuçları Tablosu:")
print(results_df)

# Sonuçları Kaydetme
results_df.to_csv("gru_overfitting_underfitting_results.csv", index=False)
print("\nSonuçlar 'gru_overfitting_underfitting_results.csv' dosyasına kaydedildi.")
# Out:
# Epoch 1/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8278 - loss: 0.4008 - val_accuracy: 0.8668 - val_loss: 0.3204
# Epoch 2/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8708 - loss: 0.3179 - val_accuracy: 0.8711 - val_loss: 0.3063
# Epoch 3/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8739 - loss: 0.3022 - val_accuracy: 0.8707 - val_loss: 0.3105
# Epoch 4/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8800 - loss: 0.2909 - val_accuracy: 0.8772 - val_loss: 0.2961
# Epoch 5/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8813 - loss: 0.2862 - val_accuracy: 0.8718 - val_loss: 0.3000
# Epoch 6/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8837 - loss: 0.2817 - val_accuracy: 0.8799 - val_loss: 0.2874
# Epoch 7/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8866 - loss: 0.2793 - val_accuracy: 0.8805 - val_loss: 0.2876
# Epoch 8/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8869 - loss: 0.2724 - val_accuracy: 0.8790 - val_loss: 0.2849
# Epoch 9/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8879 - loss: 0.2710 - val_accuracy: 0.8805 - val_loss: 0.2844
# Epoch 10/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8881 - loss: 0.2716 - val_accuracy: 0.8809 - val_loss: 0.2877
# Epoch 1/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7727 - loss: 0.5091 - val_accuracy: 0.7934 - val_loss: 0.4702
# Epoch 2/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7991 - loss: 0.4675 - val_accuracy: 0.7964 - val_loss: 0.4665
# Epoch 3/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8007 - loss: 0.4621 - val_accuracy: 0.7940 - val_loss: 0.4644
# Epoch 4/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8001 - loss: 0.4591 - val_accuracy: 0.7968 - val_loss: 0.4644
# Epoch 5/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8034 - loss: 0.4602 - val_accuracy: 0.7957 - val_loss: 0.4672
# Epoch 6/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8035 - loss: 0.4564 - val_accuracy: 0.7975 - val_loss: 0.4589
# Epoch 7/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8054 - loss: 0.4509 - val_accuracy: 0.7987 - val_loss: 0.4593
# Epoch 8/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8017 - loss: 0.4554 - val_accuracy: 0.8008 - val_loss: 0.4577
# Epoch 9/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8080 - loss: 0.4456 - val_accuracy: 0.7980 - val_loss: 0.4564
# Epoch 10/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8076 - loss: 0.4484 - val_accuracy: 0.8001 - val_loss: 0.4562
# Epoch 1/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8662 - loss: 0.3399 - val_accuracy: 0.8642 - val_loss: 0.3262
# Epoch 2/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8667 - loss: 0.3145 - val_accuracy: 0.8628 - val_loss: 0.3285
# Epoch 3/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8689 - loss: 0.3105 - val_accuracy: 0.8629 - val_loss: 0.3372
# Epoch 4/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8698 - loss: 0.3075 - val_accuracy: 0.8628 - val_loss: 0.3301
# Epoch 5/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8704 - loss: 0.3073 - val_accuracy: 0.8632 - val_loss: 0.3282
# Epoch 6/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8651 - loss: 0.3139 - val_accuracy: 0.8631 - val_loss: 0.3330
# Epoch 7/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8687 - loss: 0.3093 - val_accuracy: 0.8636 - val_loss: 0.3248
# Epoch 8/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8668 - loss: 0.3137 - val_accuracy: 0.8638 - val_loss: 0.3269
# Epoch 9/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8653 - loss: 0.3149 - val_accuracy: 0.8631 - val_loss: 0.3254
# Epoch 10/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8674 - loss: 0.3070 - val_accuracy: 0.8638 - val_loss: 0.3255
# Performans Sonuçları Tablosu:
#     Reduction Model  Train Accuracy (%)  Test Accuracy (%)  Train Loss  \
# 0  No PCA/LDA   GRU           88.913077          88.090473    0.269078
# 1         PCA   GRU           80.793673          80.014008    0.447061
# 2         LDA   GRU           86.753738          86.379105    0.309636
#
#    Test Loss  Overfitting  Underfitting
# 0   0.287743        False         False
# 1   0.456223        False         False
# 2   0.325542        False         False
#
# Sonuçlar 'gru_overfitting_underfitting_results.csv' dosyasına kaydedildi.
