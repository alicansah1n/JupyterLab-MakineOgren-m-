# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout, Input

# %%
data= pd.read_csv(r"C:\Users\hsynt\Downloads\Selcuk Abi\Selcuk Abi\VeriSeti2.csv")

# %%
# Özellik ve Hedef Ayrımı
X = data.drop(columns=['Target_10', 'adjclose'])
y = data['Target_10']

# Zaman Serisi Formatına Getirme
def create_sequences(data, target, seq_length):
    sequences, targets = [], []
    for i in range(len(data) - seq_length):
        sequences.append(data[i:i + seq_length])
        targets.append(target[i + seq_length])
    return np.array(sequences), np.array(targets)

SEQ_LENGTH = 10
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_seq, y_seq = create_sequences(X_scaled, y.values, SEQ_LENGTH)

# Eğitim ve test kümelerinin oluşturulması
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.2, random_state=42, stratify=y_seq)

# PCA ve LDA Veri Hazırlığı
X_flat = X_seq.reshape(X_seq.shape[0], -1)  # Düzleştirilmiş veri

pca = PCA(n_components=10)
X_train_pca = pca.fit_transform(X_train.reshape(X_train.shape[0], -1))
X_test_pca = pca.transform(X_test.reshape(X_test.shape[0], -1))

lda = LDA(n_components=1)
X_train_lda = lda.fit_transform(X_train.reshape(X_train.shape[0], -1), y_train)
X_test_lda = lda.transform(X_test.reshape(X_test.shape[0], -1))

# GRU Modeli Tanımlama
def build_gru_model(input_shape):
    model = Sequential([
        Input(shape=input_shape),
        GRU(64, activation='relu', return_sequences=False),
        Dropout(0.2),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Performans Hesaplama
results = []

for reduction, X_tr, X_te, y_tr, y_te in zip(
    ['No PCA/LDA', 'PCA', 'LDA'],
    [X_train, X_train_pca, X_train_lda],
    [X_test, X_test_pca, X_test_lda],
    [y_train, y_train, y_train],
    [y_test, y_test, y_test]
):
    if reduction == 'No PCA/LDA':
        X_tr = X_tr.reshape(X_tr.shape[0], X_tr.shape[1], X_tr.shape[2])  # 3D giriş
        X_te = X_te.reshape(X_te.shape[0], X_te.shape[1], X_te.shape[2])
    else:
        # PCA ve LDA için 2D giriş olarak kullanılır
        X_tr = X_tr.reshape(X_tr.shape[0], -1, 1)
        X_te = X_te.reshape(X_te.shape[0], -1, 1)

    gru_model = build_gru_model(X_tr.shape[1:])
    history = gru_model.fit(X_tr, y_tr, epochs=10, batch_size=32, verbose=1, validation_data=(X_te, y_te))

    # Eğitim ve Test Kayıpları
    train_loss, train_accuracy = history.history['loss'][-1], history.history['accuracy'][-1] * 100
    test_loss, test_accuracy = history.history['val_loss'][-1], history.history['val_accuracy'][-1] * 100

    results.append({
        'Reduction': reduction,
        'Model': 'GRU',
        'Train Accuracy (%)': train_accuracy,
        'Test Accuracy (%)': test_accuracy,
        'Train Loss': train_loss,
        'Test Loss': test_loss
    })

# Performans Sonuçlarını Görselleştirme
results_df = pd.DataFrame(results)

# Performans Sonuçları Tablosu
print("Performans Sonuçları Tablosu:")
print(results_df)

# Sonuçları Kaydetme
results_df.to_csv("gru_performance_results.csv", index=False)
print("\nSonuçlar 'gru_performance_results.csv' dosyasına kaydedildi.")
# Out:
# Epoch 1/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8225 - loss: 0.4015 - val_accuracy: 0.8676 - val_loss: 0.3185
# Epoch 2/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8683 - loss: 0.3139 - val_accuracy: 0.8729 - val_loss: 0.3039
# Epoch 3/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8785 - loss: 0.2933 - val_accuracy: 0.8708 - val_loss: 0.2989
# Epoch 4/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8835 - loss: 0.2914 - val_accuracy: 0.8761 - val_loss: 0.2992
# Epoch 5/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8821 - loss: 0.2844 - val_accuracy: 0.8815 - val_loss: 0.2911
# Epoch 6/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8869 - loss: 0.2780 - val_accuracy: 0.8815 - val_loss: 0.2877
# Epoch 7/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8881 - loss: 0.2740 - val_accuracy: 0.8812 - val_loss: 0.2907
# Epoch 8/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8845 - loss: 0.2766 - val_accuracy: 0.8841 - val_loss: 0.2850
# Epoch 9/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8905 - loss: 0.2684 - val_accuracy: 0.8812 - val_loss: 0.2856
# Epoch 10/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8917 - loss: 0.2646 - val_accuracy: 0.8788 - val_loss: 0.2884
# Epoch 1/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.6811 - loss: 0.6028 - val_accuracy: 0.7871 - val_loss: 0.4817
# Epoch 2/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7913 - loss: 0.4755 - val_accuracy: 0.7942 - val_loss: 0.4728
# Epoch 3/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7974 - loss: 0.4707 - val_accuracy: 0.7933 - val_loss: 0.4699
# Epoch 4/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7941 - loss: 0.4687 - val_accuracy: 0.7902 - val_loss: 0.4764
# Epoch 5/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7964 - loss: 0.4677 - val_accuracy: 0.7943 - val_loss: 0.4711
# Epoch 6/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7984 - loss: 0.4656 - val_accuracy: 0.7955 - val_loss: 0.4700
# Epoch 7/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8005 - loss: 0.4637 - val_accuracy: 0.7963 - val_loss: 0.4696
# Epoch 8/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.7974 - loss: 0.4646 - val_accuracy: 0.7959 - val_loss: 0.4685
# Epoch 9/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.7962 - loss: 0.4658 - val_accuracy: 0.7942 - val_loss: 0.4721
# Epoch 10/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8009 - loss: 0.4579 - val_accuracy: 0.7953 - val_loss: 0.4710
# Epoch 1/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8656 - loss: 0.3823 - val_accuracy: 0.8638 - val_loss: 0.3268
# Epoch 2/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8683 - loss: 0.3154 - val_accuracy: 0.8632 - val_loss: 0.3244
# Epoch 3/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8683 - loss: 0.3117 - val_accuracy: 0.8637 - val_loss: 0.3241
# Epoch 4/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8686 - loss: 0.3125 - val_accuracy: 0.8636 - val_loss: 0.3240
# Epoch 5/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8696 - loss: 0.3117 - val_accuracy: 0.8629 - val_loss: 0.3243
# Epoch 6/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8658 - loss: 0.3155 - val_accuracy: 0.8633 - val_loss: 0.3233
# Epoch 7/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8672 - loss: 0.3103 - val_accuracy: 0.8625 - val_loss: 0.3232
# Epoch 8/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8668 - loss: 0.3110 - val_accuracy: 0.8623 - val_loss: 0.3247
# Epoch 9/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8663 - loss: 0.3139 - val_accuracy: 0.8628 - val_loss: 0.3227
# Epoch 10/10
# 1249/1249 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8687 - loss: 0.3116 - val_accuracy: 0.8633 - val_loss: 0.3223
# Performans Sonuçları Tablosu:
#     Reduction Model  Train Accuracy (%)  Test Accuracy (%)  Train Loss  \
# 0  No PCA/LDA   GRU           89.153278          87.880301    0.265587
# 1         PCA   GRU           80.105591          79.533625    0.460580
# 2         LDA   GRU           86.733723          86.329061    0.310515
#
#    Test Loss
# 0   0.288380
# 1   0.471021
# 2   0.322273
#
# Sonuçlar 'gru_performance_results.csv' dosyasına kaydedildi.
